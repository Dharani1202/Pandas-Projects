# %%
#       CARS PROJECT - 1

# 1.	Remove all the null values
# 2.	What are the different types of make in the dataset? What is the count of each Make?
# 3.	Show all the records where origin is Asia or Europe
# 4.	Remove all the records where weight is above 4000
# 5.	Increase all the values in MPG_City column by 3 
# 6.    Show the wheelbase of 105.0 in the origin of asia.
# 7.    show all different types of drivetrain in the data set and count each of drive train
# 8.   Show the wheelbase of 105 ,cylinder is equalto 6.0 and engine size is 3.0.

# %%
import pandas as pd
a=pd.read_csv('cars.csv')
a
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# 1.Remove all the null values

# %%
a.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
a=a.dropna()
a
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
a.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
# 2.What are the different types of make in the dataset? What is the count of each Make?

# %%
a.Make.unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
a['Make'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
a.Make.nunique()
# Out:
# 38

# %%
# What is the count of each Make?

# %%
a.Make.value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Lincoln           9
# Buick             9
# Mazda             9
# Mercury           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %%
a['Make'].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Lincoln           9
# Buick             9
# Mazda             9
# Mercury           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %%
# 3. Show all the records where origin is Asia or Europe

# %%
a[(a['Origin']=='Asia')|(a['Origin']=='Europe')]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
a[a['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
a.Origin.unique()
# Out:
# array(['Asia', 'Europe', 'USA'], dtype=object)

# %%
a.Origin.nunique()
# Out:
# 3

# %%
a.Origin.value_counts()
# Out:
# Origin
# Asia      156
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
a['Origin'].isin(['USA'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# Name: Origin, Length: 426, dtype: bool

# %%
a[a['Origin'].isin(['USA'])]
# Out:
#        Make                Model   Type Origin DriveTrain      MSRP   Invoice  \
# 48    Buick              Rainier    SUV    USA        All  $37,895   $34,357
# 49    Buick        Rendezvous CX    SUV    USA      Front  $26,545   $24,085
# 50    Buick   Century Custom 4dr  Sedan    USA      Front  $22,180   $20,351
# 51    Buick   LeSabre Custom 4dr  Sedan    USA      Front  $26,470   $24,282
# 52    Buick         Regal LS 4dr  Sedan    USA      Front  $24,895   $22,835
# ..      ...                  ...    ...    ...        ...       ...       ...
# 351  Saturn             lon3 4dr  Sedan    USA      Front  $15,825   $14,811
# 352  Saturn  lon2 quad coupe 2dr  Sedan    USA      Front  $14,850   $13,904
# 353  Saturn  lon3 quad coupe 2dr  Sedan    USA      Front  $16,350   $15,299
# 354  Saturn           L300-2 4dr  Sedan    USA      Front  $21,410   $19,801
# 355  Saturn               L300 2  Wagon    USA      Front  $23,560   $21,779
#
# ...

# %%
a[a['Origin'].str.contains('Asia')]
# Out:
#        Make                       Model    Type Origin DriveTrain      MSRP  \
# 0     Acura                         MDX     SUV   Asia        All  $36,945
# 1     Acura              RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2     Acura                     TSX 4dr   Sedan   Asia      Front  $26,990
# 3     Acura                      TL 4dr   Sedan   Asia      Front  $33,195
# 4     Acura                  3.5 RL 4dr   Sedan   Asia      Front  $43,755
# ..      ...                         ...     ...    ...        ...       ...
# 400  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 401  Toyota                      Tacoma   Truck   Asia       Rear  $12,800
# 402  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear  $16,495
# 403  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All  $25,935
# 404  Toyota                   Matrix XR   Wagon   Asia      Front  $16,695
#
# ...

# %%
# 4.Remove all the records where weight is above 4000

# %%
a[a['Weight']<4000]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
a[a['Weight']>4000]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %%
# 5.Increase all the values in MPG_City column by 3

# %%
a['MPG_City'].apply(lambda x:x+3)
# Out:
# 0      12
# 1      12
# 2      12
# 3      12
# 4      12
#        ..
# 427    12
# 428    12
# 429    12
# 430    12
# 431    12
# Name: MPG_City, Length: 426, dtype: int64

# %%
a['Type'].unique()
# Out:
# array(['SUV', 'Sedan', 'Sports', 'Wagon', 'Truck', 'Hybrid'], dtype=object)

# %%
a['Type'].nunique()
# Out:
# 6

# %%
a['Type'].value_counts()
# Out:
# Type
# Sedan     262
# SUV        60
# Sports     47
# Wagon      30
# Truck      24
# Hybrid      3
# Name: count, dtype: int64

# %%
a.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0         9         23.0  4451.0
# 1         2.0        4.0       200.0         9         31.0  2778.0
# 2         2.4        4.0       200.0         9         29.0  3230.0
# 3         3.2        6.0       270.0         9         28.0  3575.0
# 4         3.5        6.0       225.0         9         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
a.head(10)
# Out:
#     Make                    Model    Type  Origin DriveTrain      MSRP  \
# 0  Acura                      MDX     SUV    Asia        All  $36,945
# 1  Acura           RSX Type S 2dr   Sedan    Asia      Front  $23,820
# 2  Acura                  TSX 4dr   Sedan    Asia      Front  $26,990
# 3  Acura                   TL 4dr   Sedan    Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6  Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 7   Audi              A4 1.8T 4dr   Sedan  Europe      Front  $25,940
# 8   Audi   A41.8T convertible 2dr   Sedan  Europe      Front  $35,940
# 9   Audi               A4 3.0 4dr   Sedan  Europe      Front  $31,840
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337          3.5        6.0       265.0         9         23.0  4451.0
# ...

# %%
a.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0         9         28.0
# 428  $40,083          2.3        5.0       242.0         9         26.0
# 429  $42,573          2.9        6.0       268.0         9         26.0
# 430  $24,641          1.9        4.0       170.0         9         29.0
# 431  $33,112          2.5        5.0       208.0         9         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
# 6.    Show the wheelbase of 105.0 in the origin of asia.

a[a['Wheelbase']==105.0]
# Out:
#           Make                           Model    Type  Origin DriveTrain  \
# 2        Acura                         TSX 4dr   Sedan    Asia      Front
# 8         Audi          A41.8T convertible 2dr   Sedan  Europe      Front
# 14        Audi          A4 3.0 convertible 2dr   Sedan  Europe      Front
# 15        Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 84   Chevrolet                    Corvette 2dr  Sports     USA       Rear
# 85   Chevrolet        Corvette convertible 2dr  Sports     USA       Rear
# 108      Dodge                     Neon SE 4dr   Sedan     USA      Front
# 109      Dodge                    Neon SXT 4dr   Sedan     USA      Front
# 159      Honda                   Accord LX 2dr   Sedan    Asia      Front
# 160      Honda                   Accord EX 2dr   Sedan    Asia      Front
# 165      Honda                Accord EX V6 2dr   Sedan    Asia      Front
# 226      Lexus               IS 300 4dr manual   Sedan    Asia       Rear
# ...

# %%
a[(a['Wheelbase']==105.0)&(a['Origin']=='Asia')]
# Out:
#       Make              Model   Type Origin DriveTrain      MSRP   Invoice  \
# 2    Acura            TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 159  Honda      Accord LX 2dr  Sedan   Asia      Front  $19,860   $17,924
# 160  Honda      Accord EX 2dr  Sedan   Asia      Front  $22,260   $20,080
# 165  Honda   Accord EX V6 2dr  Sedan   Asia      Front  $26,960   $24,304
# 226  Lexus  IS 300 4dr manual  Sedan   Asia       Rear  $31,045   $27,404
# 227  Lexus    IS 300 4dr auto  Sedan   Asia       Rear  $32,415   $28,611
# 232  Lexus  IS 300 SportCross  Wagon   Asia       Rear  $32,455   $28,647
# 247  Mazda       Mazda6 i 4dr  Sedan   Asia      Front  $19,270   $17,817
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 2           2.4        4.0       200.0      22.0         29.0  3230.0
# 159         2.4        4.0       160.0      26.0         34.0  2994.0
# 160         2.4        4.0       160.0      26.0         34.0  3047.0
# ...

# %%
# 7.  show all different types of drivetrain in the data set and count each of drive train

# %%
a['DriveTrain'].nunique()
# Out:
# 3

# %%
a['DriveTrain'].unique()
# Out:
# array(['All', 'Front', 'Rear', nan], dtype=object)

# %%
a['DriveTrain'].value_counts()
# Out:
# DriveTrain
# Front    226
# Rear     110
# All       92
# Name: count, dtype: int64

# %%
# 8.   Show the wheelbase of 105 ,cylinder is equalto 6.0 and engine size is 3.0.

a[(a['Wheelbase']==105.0)&(a['Cylinders']==6.0)&(a['EngineSize']==3.0)]
# Out:
#       Make                           Model   Type  Origin DriveTrain  \
# 14    Audi          A4 3.0 convertible 2dr  Sedan  Europe      Front
# 15    Audi  A4 3.0 Quattro convertible 2dr  Sedan  Europe        All
# 165  Honda                Accord EX V6 2dr  Sedan    Asia      Front
# 226  Lexus               IS 300 4dr manual  Sedan    Asia       Rear
# 227  Lexus                 IS 300 4dr auto  Sedan    Asia       Rear
# 232  Lexus               IS 300 SportCross  Wagon    Asia       Rear
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 14   $42,490   $38,325          3.0        6.0       220.0      20.0
# 15   $44,240   $40,075          3.0        6.0       220.0      18.0
# 165  $26,960   $24,304          3.0        6.0       240.0      21.0
# 226  $31,045   $27,404          3.0        6.0       215.0      18.0
# 227  $32,415   $28,611          3.0        6.0       215.0      18.0
# ...
